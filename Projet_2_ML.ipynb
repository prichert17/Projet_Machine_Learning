# %% [markdown]
# # Projet - PROJET : Machine Learning
# ## Classification automatique supervisée d’images naturelles et artificielles

# %% [markdown]
# # ------------------------------------------------------------------------------------------------
# # Première partie : Machine learning classique
# # ------------------------------------------------------------------------------------------------

# %%
# Analyse preliminaire

# Analyse par composante principale (ACP)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, balanced_accuracy_score
from sklearn.decomposition import PCA # ACP
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, cross_val_predict

from utils_ClassLm.ipynb import * # importation des fonctions utilitaires

donnee = pd.read_csv('database.csv') # lecture des donnees

# Affichage des dimensions du jeu de donnees
print("Dimensions du jeu de donnees : ", donnee.shape)
